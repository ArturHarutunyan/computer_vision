# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 1247461886978013127,
#  name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6149459696633023555
#  physical_device_desc: "device: XLA_CPU device",
#  name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 8737535145499904030
#  physical_device_desc: "device: XLA_GPU device"]

# %%
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-452c6ffbe5e8> in <module>
# ----> 1 config = tf.ConfigProto()
#       2 config.gpu_options.allow_growth = True
#
# AttributeError: module 'tensorflow' has no attribute 'ConfigProto'

# %%
# !git clone https://github.com/tensorflow/benchmarks.git
# Out:
# Cloning into 'benchmarks'...

# %%
# !cd benchmarks
# Out:
# The system cannot find the path specified.

# %%
# %cd benchmarks/scripts/tf_cnn_benchmarks
# Out:
# [WinError 3] The system cannot find the path specified: 'benchmarks/scripts/tf_cnn_benchmarks'
# C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks

# %%
# !python tf_cnn_benchmarks.py --num_gpus=1 --batch_size=1 --model=resnet50 --variable_update=parameter_server
# Out:
# TensorFlow:  2.3
# Model:       resnet50
# Dataset:     imagenet (synthetic)
# Mode:        training
# SingleSess:  False
# Batch size:  1 global
#              1 per device
# Num batches: 100
# Num epochs:  0.00
# Devices:     ['/gpu:0']
# NUMA bind:   False
# Data format: NCHW
# Optimizer:   sgd
# Variables:   parameter_server
# ==========
# Generating training model
# Initializing graph
# Running warm up
# 2020-10-23 19:47:41.532360: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2020-10-23 19:47:41.532525: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2020-10-23 19:47:43.001031: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-10-23 19:47:43.005829: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2d1cd792180 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 19:47:43.005994: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-23 19:47:43.006443: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library nvcuda.dll
# 2020-10-23 19:47:43.021140: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.635GHz coreCount: 68 deviceMemorySize: 11.00GiB deviceMemoryBandwidth: 573.69GiB/s
# 2020-10-23 19:47:43.021993: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2020-10-23 19:47:43.022695: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cublas64_10.dll'; dlerror: cublas64_10.dll not found
# 2020-10-23 19:47:43.023417: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2020-10-23 19:47:43.024119: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2020-10-23 19:47:43.024818: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cusolver64_10.dll'; dlerror: cusolver64_10.dll not found
# 2020-10-23 19:47:43.025487: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cusparse64_10.dll'; dlerror: cusparse64_10.dll not found
# 2020-10-23 19:47:43.026208: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudnn64_7.dll'; dlerror: cudnn64_7.dll not found
# 2020-10-23 19:47:43.026347: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2020-10-23 19:47:43.096927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-23 19:47:43.097057: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-23 19:47:43.097139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-23 19:47:43.098844: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2d1d968c2e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-23 19:47:43.099033: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): GeForce RTX 2080 Ti, Compute Capability 7.5
# WARNING:tensorflow:From C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py:131: conv2d (from tensorflow.python.keras.legacy_tf_layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# W1023 19:47:43.113661 24424 deprecation.py:317] From C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py:131: conv2d (from tensorflow.python.keras.legacy_tf_layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# W1023 19:47:43.116657 24424 deprecation.py:317] From C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer_v1) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py:262: max_pooling2d (from tensorflow.python.keras.legacy_tf_layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# W1023 19:47:43.140589 24424 deprecation.py:317] From C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py:262: max_pooling2d (from tensorflow.python.keras.legacy_tf_layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py:2252: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# W1023 19:47:45.110336 24424 deprecation.py:317] From C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py:2252: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# 2020-10-23 19:47:46.273490: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce RTX 2080 Ti computeCapability: 7.5
# coreClock: 1.635GHz coreCount: 68 deviceMemorySize: 11.00GiB deviceMemoryBandwidth: 573.69GiB/s
# 2020-10-23 19:47:46.274341: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudart64_101.dll'; dlerror: cudart64_101.dll not found
# 2020-10-23 19:47:46.275079: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cublas64_10.dll'; dlerror: cublas64_10.dll not found
# 2020-10-23 19:47:46.275762: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cufft64_10.dll'; dlerror: cufft64_10.dll not found
# 2020-10-23 19:47:46.276467: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'curand64_10.dll'; dlerror: curand64_10.dll not found
# 2020-10-23 19:47:46.277172: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cusolver64_10.dll'; dlerror: cusolver64_10.dll not found
# 2020-10-23 19:47:46.277885: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cusparse64_10.dll'; dlerror: cusparse64_10.dll not found
# 2020-10-23 19:47:46.278544: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'cudnn64_7.dll'; dlerror: cudnn64_7.dll not found
# 2020-10-23 19:47:46.278672: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1753] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2020-10-23 19:47:46.278991: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-23 19:47:46.279120: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-23 19:47:46.279207: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-23 19:47:46.323425: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# VariableV2: CPU
# Assign: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   tower_0/v/gpu_cached_inputs (VariableV2) /device:GPU:0
#   tower_0/v/gpu_cached_inputs/Assign (Assign) /device:GPU:0
#   tower_0/v/gpu_cached_inputs/read (Identity) /device:GPU:0
#   report_uninitialized_variables/IsVariableInitialized_268 (IsVariableInitialized) /device:GPU:0
#
# 2020-10-23 19:47:46.324367: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Add: CPU XLA_CPU XLA_GPU
# Const: CPU XLA_CPU XLA_GPU
# TruncatedNormal: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Mul: CPU XLA_CPU XLA_GPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/conv0/conv2d/kernel/Initializer/truncated_normal/shape (Const)
#   v/cg/conv0/conv2d/kernel/Initializer/truncated_normal/mean (Const)
#   v/cg/conv0/conv2d/kernel/Initializer/truncated_normal/stddev (Const)
#   v/cg/conv0/conv2d/kernel/Initializer/truncated_normal/TruncatedNormal (TruncatedNormal)
#   v/cg/conv0/conv2d/kernel/Initializer/truncated_normal/mul (Mul)
#   v/cg/conv0/conv2d/kernel/Initializer/truncated_normal (Add)
#   v/cg/conv0/conv2d/kernel (VariableV2) /gpu:0
#   v/cg/conv0/conv2d/kernel/Assign (Assign) /gpu:0
#   v/cg/conv0/conv2d/kernel/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/conv0/conv2d/kernel/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_7 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_1 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.326019: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/conv0/batchnorm0/gamma/Initializer/ones (Const)
#   v/cg/conv0/batchnorm0/gamma (VariableV2) /gpu:0
#   v/cg/conv0/batchnorm0/gamma/Assign (Assign) /gpu:0
#   v/cg/conv0/batchnorm0/gamma/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/conv0/batchnorm0/gamma/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_4 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_2 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.327286: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/conv0/batchnorm0/beta/Initializer/zeros (Const)
#   v/cg/conv0/batchnorm0/beta (VariableV2) /gpu:0
#   v/cg/conv0/batchnorm0/beta/Assign (Assign) /gpu:0
#   v/cg/conv0/batchnorm0/beta/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/conv0/batchnorm0/beta/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_3 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_3 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.328517: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# Mul: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
# Sub: CPU XLA_CPU XLA_GPU
# AssignSub: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/conv0/batchnorm0/moving_mean/Initializer/zeros (Const)
#   v/cg/conv0/batchnorm0/moving_mean (VariableV2) /gpu:0
#   v/cg/conv0/batchnorm0/moving_mean/Assign (Assign) /gpu:0
#   v/cg/conv0/batchnorm0/moving_mean/read (Identity) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg/sub/x (Const) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg/sub (Sub) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg/sub_1 (Sub) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg/mul (Mul) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg (AssignSub) /gpu:0
#   save/Assign_5 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_4 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.329854: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# Mul: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
# Sub: CPU XLA_CPU XLA_GPU
# AssignSub: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/conv0/batchnorm0/moving_variance/Initializer/ones (Const)
#   v/cg/conv0/batchnorm0/moving_variance (VariableV2) /gpu:0
#   v/cg/conv0/batchnorm0/moving_variance/Assign (Assign) /gpu:0
#   v/cg/conv0/batchnorm0/moving_variance/read (Identity) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg_1/sub/x (Const) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg_1/sub (Sub) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg_1/sub_1 (Sub) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg_1/mul (Mul) /gpu:0
#   tower_0/v/cg/conv0/batchnorm0/AssignMovingAvg_1 (AssignSub) /gpu:0
#   save/Assign_6 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_5 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.331208: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Add: CPU XLA_CPU XLA_GPU
# Const: CPU XLA_CPU XLA_GPU
# TruncatedNormal: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Mul: CPU XLA_CPU XLA_GPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv1/conv2d/kernel/Initializer/truncated_normal/shape (Const)
#   v/cg/resnet_v10/conv1/conv2d/kernel/Initializer/truncated_normal/mean (Const)
#   v/cg/resnet_v10/conv1/conv2d/kernel/Initializer/truncated_normal/stddev (Const)
#   v/cg/resnet_v10/conv1/conv2d/kernel/Initializer/truncated_normal/TruncatedNormal (TruncatedNormal)
#   v/cg/resnet_v10/conv1/conv2d/kernel/Initializer/truncated_normal/mul (Mul)
#   v/cg/resnet_v10/conv1/conv2d/kernel/Initializer/truncated_normal (Add)
#   v/cg/resnet_v10/conv1/conv2d/kernel (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv1/conv2d/kernel/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv1/conv2d/kernel/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv1/conv2d/kernel/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_12 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_6 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.332733: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv1/batchnorm1/gamma/Initializer/ones (Const)
#   v/cg/resnet_v10/conv1/batchnorm1/gamma (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv1/batchnorm1/gamma/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv1/batchnorm1/gamma/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv1/batchnorm1/gamma/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_9 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_7 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.334094: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv1/batchnorm1/beta/Initializer/zeros (Const)
#   v/cg/resnet_v10/conv1/batchnorm1/beta (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv1/batchnorm1/beta/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv1/batchnorm1/beta/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv1/batchnorm1/beta/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_8 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_8 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.335321: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# Mul: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
# Sub: CPU XLA_CPU XLA_GPU
# AssignSub: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv1/batchnorm1/moving_mean/Initializer/zeros (Const)
#   v/cg/resnet_v10/conv1/batchnorm1/moving_mean (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv1/batchnorm1/moving_mean/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv1/batchnorm1/moving_mean/read (Identity) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg/sub/x (Const) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg/sub (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg/sub_1 (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg/mul (Mul) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg (AssignSub) /gpu:0
#   save/Assign_10 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_9 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.336641: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# Mul: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
# Sub: CPU XLA_CPU XLA_GPU
# AssignSub: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv1/batchnorm1/moving_variance/Initializer/ones (Const)
#   v/cg/resnet_v10/conv1/batchnorm1/moving_variance (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv1/batchnorm1/moving_variance/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv1/batchnorm1/moving_variance/read (Identity) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg_1/sub/x (Const) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg_1/sub (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg_1/sub_1 (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg_1/mul (Mul) /gpu:0
#   tower_0/v/cg/resnet_v10/conv1/batchnorm1/AssignMovingAvg_1 (AssignSub) /gpu:0
#   save/Assign_11 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_10 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.338120: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Add: CPU XLA_CPU XLA_GPU
# Const: CPU XLA_CPU XLA_GPU
# TruncatedNormal: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Mul: CPU XLA_CPU XLA_GPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv2/conv2d/kernel/Initializer/truncated_normal/shape (Const)
#   v/cg/resnet_v10/conv2/conv2d/kernel/Initializer/truncated_normal/mean (Const)
#   v/cg/resnet_v10/conv2/conv2d/kernel/Initializer/truncated_normal/stddev (Const)
#   v/cg/resnet_v10/conv2/conv2d/kernel/Initializer/truncated_normal/TruncatedNormal (TruncatedNormal)
#   v/cg/resnet_v10/conv2/conv2d/kernel/Initializer/truncated_normal/mul (Mul)
#   v/cg/resnet_v10/conv2/conv2d/kernel/Initializer/truncated_normal (Add)
#   v/cg/resnet_v10/conv2/conv2d/kernel (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv2/conv2d/kernel/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv2/conv2d/kernel/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv2/conv2d/kernel/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_17 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_11 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.339799: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv2/batchnorm2/gamma/Initializer/ones (Const)
#   v/cg/resnet_v10/conv2/batchnorm2/gamma (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv2/batchnorm2/gamma/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv2/batchnorm2/gamma/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv2/batchnorm2/gamma/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_14 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_12 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.341012: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv2/batchnorm2/beta/Initializer/zeros (Const)
#   v/cg/resnet_v10/conv2/batchnorm2/beta (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv2/batchnorm2/beta/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv2/batchnorm2/beta/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv2/batchnorm2/beta/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_13 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_13 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.342159: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# Mul: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
# Sub: CPU XLA_CPU XLA_GPU
# AssignSub: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv2/batchnorm2/moving_mean/Initializer/zeros (Const)
#   v/cg/resnet_v10/conv2/batchnorm2/moving_mean (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv2/batchnorm2/moving_mean/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv2/batchnorm2/moving_mean/read (Identity) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg/sub/x (Const) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg/sub (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg/sub_1 (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg/mul (Mul) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg (AssignSub) /gpu:0
#   save/Assign_15 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_14 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.343646: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# Mul: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
# Sub: CPU XLA_CPU XLA_GPU
# AssignSub: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv2/batchnorm2/moving_variance/Initializer/ones (Const)
#   v/cg/resnet_v10/conv2/batchnorm2/moving_variance (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv2/batchnorm2/moving_variance/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv2/batchnorm2/moving_variance/read (Identity) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg_1/sub/x (Const) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg_1/sub (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg_1/sub_1 (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg_1/mul (Mul) /gpu:0
#   tower_0/v/cg/resnet_v10/conv2/batchnorm2/AssignMovingAvg_1 (AssignSub) /gpu:0
#   save/Assign_16 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_15 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.345033: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Add: CPU XLA_CPU XLA_GPU
# Const: CPU XLA_CPU XLA_GPU
# TruncatedNormal: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Mul: CPU XLA_CPU XLA_GPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv3/conv2d/kernel/Initializer/truncated_normal/shape (Const)
#   v/cg/resnet_v10/conv3/conv2d/kernel/Initializer/truncated_normal/mean (Const)
#   v/cg/resnet_v10/conv3/conv2d/kernel/Initializer/truncated_normal/stddev (Const)
#   v/cg/resnet_v10/conv3/conv2d/kernel/Initializer/truncated_normal/TruncatedNormal (TruncatedNormal)
#   v/cg/resnet_v10/conv3/conv2d/kernel/Initializer/truncated_normal/mul (Mul)
#   v/cg/resnet_v10/conv3/conv2d/kernel/Initializer/truncated_normal (Add)
#   v/cg/resnet_v10/conv3/conv2d/kernel (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv3/conv2d/kernel/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv3/conv2d/kernel/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv3/conv2d/kernel/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_22 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_16 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.346644: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv3/batchnorm3/gamma/Initializer/ones (Const)
#   v/cg/resnet_v10/conv3/batchnorm3/gamma (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv3/batchnorm3/gamma/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv3/batchnorm3/gamma/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv3/batchnorm3/gamma/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_19 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_17 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.347742: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv3/batchnorm3/beta/Initializer/zeros (Const)
#   v/cg/resnet_v10/conv3/batchnorm3/beta (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv3/batchnorm3/beta/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv3/batchnorm3/beta/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv3/batchnorm3/beta/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_18 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_18 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.348914: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# Mul: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
# Sub: CPU XLA_CPU XLA_GPU
# AssignSub: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv3/batchnorm3/moving_mean/Initializer/zeros (Const)
#   v/cg/resnet_v10/conv3/batchnorm3/moving_mean (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv3/batchnorm3/moving_mean/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv3/batchnorm3/moving_mean/read (Identity) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg/sub/x (Const) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg/sub (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg/sub_1 (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg/mul (Mul) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg (AssignSub) /gpu:0
#   save/Assign_20 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_19 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.350319: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# Mul: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# IsVariableInitialized: CPU
# Sub: CPU XLA_CPU XLA_GPU
# AssignSub: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv3/batchnorm3/moving_variance/Initializer/ones (Const)
#   v/cg/resnet_v10/conv3/batchnorm3/moving_variance (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv3/batchnorm3/moving_variance/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv3/batchnorm3/moving_variance/read (Identity) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg_1/sub/x (Const) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg_1/sub (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg_1/sub_1 (Sub) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg_1/mul (Mul) /gpu:0
#   tower_0/v/cg/resnet_v10/conv3/batchnorm3/AssignMovingAvg_1 (AssignSub) /gpu:0
#   save/Assign_21 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_20 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.351867: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Add: CPU XLA_CPU XLA_GPU
# Const: CPU XLA_CPU XLA_GPU
# TruncatedNormal: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Mul: CPU XLA_CPU XLA_GPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv4/conv2d/kernel/Initializer/truncated_normal/shape (Const)
#   v/cg/resnet_v10/conv4/conv2d/kernel/Initializer/truncated_normal/mean (Const)
#   v/cg/resnet_v10/conv4/conv2d/kernel/Initializer/truncated_normal/stddev (Const)
#   v/cg/resnet_v10/conv4/conv2d/kernel/Initializer/truncated_normal/TruncatedNormal (TruncatedNormal)
#   v/cg/resnet_v10/conv4/conv2d/kernel/Initializer/truncated_normal/mul (Mul)
#   v/cg/resnet_v10/conv4/conv2d/kernel/Initializer/truncated_normal (Add)
#   v/cg/resnet_v10/conv4/conv2d/kernel (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv4/conv2d/kernel/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv4/conv2d/kernel/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv4/conv2d/kernel/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_27 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_21 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.353510: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# Const: CPU XLA_CPU XLA_GPU
# VariableV2: CPU
# Identity: CPU XLA_CPU XLA_GPU
# ApplyGradientDescent: CPU
# IsVariableInitialized: CPU
#
# Colocation members, user-requested devices, and framework assigned devices, if any:
#   v/cg/resnet_v10/conv4/batchnorm4/gamma/Initializer/ones (Const)
#   v/cg/resnet_v10/conv4/batchnorm4/gamma (VariableV2) /gpu:0
#   v/cg/resnet_v10/conv4/batchnorm4/gamma/Assign (Assign) /gpu:0
#   v/cg/resnet_v10/conv4/batchnorm4/gamma/read (Identity) /gpu:0
#   append_apply_gradient_ops/GradientDescent/update_v/cg/resnet_v10/conv4/batchnorm4/gamma/ApplyGradientDescent (ApplyGradientDescent) /gpu:0
#   save/Assign_24 (Assign) /gpu:0
#   report_uninitialized_variables/IsVariableInitialized_22 (IsVariableInitialized) /gpu:0
#
# 2020-10-23 19:47:46.354622: W tensorflow/core/common_runtime/colocation_graph.cc:1139] Failed to place the graph without changing the devices of some resources. Some of the operations (that had to be colocated with resource generating operations) are not supported on the resources' devices. Current candidate devices are [
#   /job:localhost/replica:0/task:0/device:CPU:0].
# See below for details of this colocation group:
# Colocation Debug Info:
# Colocation group had the following types and supported devices:
# Root Member(assigned_device_name_index_=-1 requested_device_name_='/device:GPU:0' assigned_device_name_='' resource_device_name_='/device:GPU:0' supported_device_types_=[CPU] possible_devices_=[]
# Assign: CPU
# ...
#     return converted_call(f, args, kwargs, options=options)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 532, in converted_call
#     return _call_unconverted(f, args, kwargs, options)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 339, in _call_unconverted
#     return f(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\layers\pooling.py", line 291, in call
#     outputs = self.pool_function(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py", line 201, in wrapper
#     return target(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 4514, in max_pool
#     return gen_nn_ops.max_pool(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py", line 5267, in max_pool
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 742, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3477, in _create_op_internal
#     ret = Operation(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1949, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# I1023 19:47:47.575975 24424 coordinator.py:222] Error reported to Coordinator: <class 'tensorflow.python.framework.errors_impl.InvalidArgumentError'>, Default MaxPoolingOp only supports NHWC on device type CPU
# 	 [[node tower_0/v/cg/mpool0/MaxPool (defined at C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py:262) ]]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node tower_0/v/cg/mpool0/MaxPool:
#  tower_0/v/cg/conv0/Relu (defined at C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py:233)
#
# Original stack trace for 'tower_0/v/cg/mpool0/MaxPool':
#   File "tf_cnn_benchmarks.py", line 73, in <module>
#     app.run(main)  # Raises error on invalid flags, unlike tf.app.run()
#   File "C:\Users\Artur\anaconda3\lib\site-packages\absl\app.py", line 300, in run
#     _run_main(main, args)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\absl\app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "tf_cnn_benchmarks.py", line 68, in main
#     bench.run()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 1883, in run
#     return self._benchmark_train()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2079, in _benchmark_train
#     build_result = self._build_graph()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2111, in _build_graph
#     (input_producer_op, enqueue_ops, fetches) = self._build_model()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2829, in _build_model
#     results = self.add_forward_pass_and_gradients(
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 3351, in add_forward_pass_and_gradients
#     outputs = maybe_compile(forward_pass_and_gradients, self.params)
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 3548, in maybe_compile
#     return computation()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 3204, in forward_pass_and_gradients
#     build_network_result = self.model.build_network(
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\models\model.py", line 293, in build_network
#     self.add_inference(network)
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\models\resnet_model.py", line 309, in add_inference
#     cnn.mpool(3, 3, 2, 2, mode='SAME')
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py", line 291, in mpool
#     return self._pool('mpool', pooling_layers.max_pooling2d, k_height, k_width,
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py", line 262, in _pool
#     pool = pool_function(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 324, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\pooling.py", line 311, in max_pooling2d
#     return layer.apply(inputs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 324, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py", line 1701, in apply
#     return self.__call__(inputs, *args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\base.py", line 547, in __call__
#     outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py", line 776, in __call__
#     outputs = call_fn(cast_inputs, *args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 255, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 532, in converted_call
#     return _call_unconverted(f, args, kwargs, options)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 339, in _call_unconverted
#     return f(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\layers\pooling.py", line 291, in call
#     outputs = self.pool_function(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py", line 201, in wrapper
#     return target(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 4514, in max_pool
#     return gen_nn_ops.max_pool(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py", line 5267, in max_pool
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 742, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3477, in _create_op_internal
#     ret = Operation(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1949, in __init__
#     self._traceback = tf_stack.extract_stack()
#
# Traceback (most recent call last):
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1365, in _do_call
#     return fn(*args)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1349, in _run_fn
#     return self._call_tf_sessionrun(options, feed_dict, fetch_list,
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1441, in _call_tf_sessionrun
#     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Default MaxPoolingOp only supports NHWC on device type CPU
# 	 [[{{node tower_0/v/cg/mpool0/MaxPool}}]]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "tf_cnn_benchmarks.py", line 73, in <module>
#     app.run(main)  # Raises error on invalid flags, unlike tf.app.run()
#   File "C:\Users\Artur\anaconda3\lib\site-packages\absl\app.py", line 300, in run
#     _run_main(main, args)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\absl\app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "tf_cnn_benchmarks.py", line 68, in main
#     bench.run()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 1883, in run
#     return self._benchmark_train()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2088, in _benchmark_train
#     return self._benchmark_graph(result_to_benchmark, eval_build_results)
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2293, in _benchmark_graph
#     stats = self.benchmark_with_session(
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2424, in benchmark_with_session
#     (summary_str, last_average_loss) = benchmark_one_step(
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 870, in benchmark_one_step
#     results = sess.run(fetches, options=run_options, run_metadata=run_metadata)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 957, in run
#     result = self._run(None, fetches, feed_dict, options_ptr,
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1180, in _run
#     results = self._do_run(handle, final_targets, final_fetches,
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1358, in _do_run
#     return self._do_call(_run_fn, feeds, fetches, targets, options,
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\client\session.py", line 1384, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.InvalidArgumentError: Default MaxPoolingOp only supports NHWC on device type CPU
# 	 [[node tower_0/v/cg/mpool0/MaxPool (defined at C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py:262) ]]
#
# Errors may have originated from an input operation.
# Input Source operations connected to node tower_0/v/cg/mpool0/MaxPool:
#  tower_0/v/cg/conv0/Relu (defined at C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py:233)
#
# Original stack trace for 'tower_0/v/cg/mpool0/MaxPool':
#   File "tf_cnn_benchmarks.py", line 73, in <module>
#     app.run(main)  # Raises error on invalid flags, unlike tf.app.run()
#   File "C:\Users\Artur\anaconda3\lib\site-packages\absl\app.py", line 300, in run
#     _run_main(main, args)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\absl\app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "tf_cnn_benchmarks.py", line 68, in main
#     bench.run()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 1883, in run
#     return self._benchmark_train()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2079, in _benchmark_train
#     build_result = self._build_graph()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2111, in _build_graph
#     (input_producer_op, enqueue_ops, fetches) = self._build_model()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 2829, in _build_model
#     results = self.add_forward_pass_and_gradients(
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 3351, in add_forward_pass_and_gradients
#     outputs = maybe_compile(forward_pass_and_gradients, self.params)
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 3548, in maybe_compile
#     return computation()
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\benchmark_cnn.py", line 3204, in forward_pass_and_gradients
#     build_network_result = self.model.build_network(
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\models\model.py", line 293, in build_network
#     self.add_inference(network)
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\models\resnet_model.py", line 309, in add_inference
#     cnn.mpool(3, 3, 2, 2, mode='SAME')
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py", line 291, in mpool
#     return self._pool('mpool', pooling_layers.max_pooling2d, k_height, k_width,
#   File "C:\Users\Artur\PycharmProjects\pythonProject1\Sergey\benchmarks\scripts\tf_cnn_benchmarks\convnet_builder.py", line 262, in _pool
#     pool = pool_function(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 324, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\pooling.py", line 311, in max_pooling2d
#     return layer.apply(inputs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py", line 324, in new_func
#     return func(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py", line 1701, in apply
#     return self.__call__(inputs, *args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\base.py", line 547, in __call__
#     outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py", line 776, in __call__
#     outputs = call_fn(cast_inputs, *args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 255, in wrapper
#     return converted_call(f, args, kwargs, options=options)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 532, in converted_call
#     return _call_unconverted(f, args, kwargs, options)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 339, in _call_unconverted
#     return f(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\keras\layers\pooling.py", line 291, in call
#     outputs = self.pool_function(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py", line 201, in wrapper
#     return target(*args, **kwargs)
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\ops\nn_ops.py", line 4514, in max_pool
#     return gen_nn_ops.max_pool(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py", line 5267, in max_pool
#     _, _, _op, _outputs = _op_def_library._apply_op_helper(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py", line 742, in _apply_op_helper
#     op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 3477, in _create_op_internal
#     ret = Operation(
#   File "C:\Users\Artur\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py", line 1949, in __init__
#     self._traceback = tf_stack.extract_stack()
